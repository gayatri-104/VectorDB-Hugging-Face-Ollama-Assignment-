# %% [markdown]
# # Question 1: What is a Vector Database (VectorDB) and how is it different from traditional databases?
#
# ## Answer
#
# A **Vector Database (VectorDB)** is a specialized database designed to store, manage, and search high-dimensional vector embeddings generated by machine learning models. These embeddings represent data such as text, images, audio, and videos in numerical form, enabling semantic similarity searches.
#
# ### Difference Between VectorDB and Traditional Databases
#
# | Feature        | Vector Database                       | Traditional Database                      |
# | -------------- | ------------------------------------- | ----------------------------------------- |
# | Data Storage   | Stores vector embeddings              | Stores structured data (rows and columns) |
# | Search Method  | Similarity search (nearest neighbor)  | Exact match and SQL queries               |
# | Data Type      | Unstructured and semi-structured data | Structured data                           |
# | AI Integration | Designed for AI/ML applications       | Limited AI capabilities                   |
# | Retrieval      | Semantic search based on meaning      | Keyword-based search                      |
#
# ### Example
#
# If a user searches for **"cars with eco-friendly engines"**, a VectorDB can retrieve documents related to **electric vehicles**, even if those exact words are not present. A traditional database typically relies on exact keyword matching.
#
# ### Conclusion
#
# Vector Databases are essential for modern AI applications such as semantic search, recommendation systems, Retrieval-Augmented Generation (RAG), and conversational AI.
#
# ---
#
# # Question 2: Explain the various types of VectorDBs available and describe their suitability for different use cases.
#
# ## Answer
#
# Several Vector Databases are available, each designed for specific AI and machine learning requirements.
#
# ### 1. ChromaDB
#
# **Description:**
# An open-source vector database designed specifically for AI and LLM applications.
#
# **Use Cases:**
#
# * RAG systems
# * Chatbots
# * Document search
# * Local AI projects
#
# **Advantages:**
#
# * Easy to use
# * Lightweight
# * Python-friendly
#
# ---
#
# ### 2. Pinecone
#
# **Description:**
# A fully managed cloud-based vector database.
#
# **Use Cases:**
#
# * Enterprise AI applications
# * Large-scale semantic search
# * Production deployments
#
# **Advantages:**
#
# * High scalability
# * Managed infrastructure
# * Real-time updates
#
# ---
#
# ### 3. Weaviate
#
# **Description:**
# An open-source vector database with built-in machine learning modules.
#
# **Use Cases:**
#
# * Knowledge graphs
# * Semantic search
# * Recommendation engines
#
# **Advantages:**
#
# * Hybrid search support
# * GraphQL API
# * Cloud and self-hosted options
#
# ---
#
# ### 4. Milvus
#
# **Description:**
# A highly scalable open-source vector database optimized for large datasets.
#
# **Use Cases:**
#
# * Image search
# * Video retrieval
# * Large-scale AI systems
#
# **Advantages:**
#
# * Billions of vectors support
# * High performance
# * Distributed architecture
#
# ---
#
# ### 5. Qdrant
#
# **Description:**
# A vector similarity search engine focused on filtering and metadata support.
#
# **Use Cases:**
#
# * Recommendation systems
# * Personalized search
# * AI assistants
#
# **Advantages:**
#
# * Fast retrieval
# * Strong filtering capabilities
# * Easy deployment
#
# ---
#
# ### Conclusion
#
# Different VectorDBs serve different needs. ChromaDB is ideal for learning and prototyping, Pinecone for enterprise cloud deployments, Milvus for large-scale datasets, Weaviate for semantic knowledge systems, and Qdrant for recommendation-based applications.
#
# ---
#
# # Question 3: Why is Chroma DB considered important in the context of AI/ML projects? Describe its key features.
#
# ## Answer
#
# ### Introduction
#
# **Chroma DB** is an open-source vector database designed specifically for Artificial Intelligence and Machine Learning applications. It simplifies the storage and retrieval of vector embeddings generated by modern AI models.
#
# ### Importance in AI/ML Projects
#
# 1. Supports semantic search using embeddings.
# 2. Enhances Retrieval-Augmented Generation (RAG) systems.
# 3. Enables efficient document retrieval for LLMs.
# 4. Provides fast similarity search.
# 5. Integrates easily with Hugging Face, LangChain, and Ollama.
#
# ### Key Features of Chroma DB
#
# #### 1. Vector Storage
#
# Stores embeddings generated from text, images, audio, and other data.
#
# #### 2. Semantic Search
#
# Retrieves information based on meaning rather than exact keywords.
#
# #### 3. Lightweight and Open Source
#
# Can run locally without requiring complex infrastructure.
#
# #### 4. Metadata Support
#
# Allows storage of additional information alongside vectors.
#
# #### 5. Easy Python Integration
#
# ```python
# import chromadb
#
# client = chromadb.Client()
# collection = client.create_collection("documents")
# ```
#
# #### 6. Fast Similarity Search
#
# Uses vector distance metrics to quickly identify similar documents.
#
# #### 7. RAG Support
#
# Works efficiently with Large Language Models to provide contextual responses.
#
# ### Applications
#
# * AI Chatbots
# * Question Answering Systems
# * Recommendation Systems
# * Knowledge Bases
# * Semantic Document Search
#
# ### Conclusion
#
# Chroma DB is important because it provides efficient vector storage, semantic retrieval, and seamless integration with modern AI frameworks, making it a popular choice for AI/ML projects.
#
# ---
#
# # Question 4: What are the benefits of using Hugging Face Hub for generative AI tasks?
#
# ## Answer
#
# ### Introduction
#
# The Hugging Face Hub is a centralized platform that provides access to thousands of pre-trained machine learning and generative AI models. It enables developers and researchers to quickly build AI applications without training models from scratch.
#
# ### Benefits of Hugging Face Hub
#
# ### 1. Large Collection of Pre-trained Models
#
# Provides access to models for:
#
# * Text Generation
# * Summarization
# * Translation
# * Question Answering
# * Sentiment Analysis
# * Image Generation
#
# Examples include:
#
# * GPT-2
# * BERT
# * Llama 2
# * T5
#
# ### 2. Easy Integration
#
# Models can be loaded with just a few lines of code:
#
# ```python
# from transformers import pipeline
#
# generator = pipeline(
#     "text-generation",
#     model="gpt2"
# )
# ```
#
# ### 3. Saves Time and Resources
#
# Developers can use existing models instead of spending time and computational resources on training from scratch.
#
# ### 4. Fine-Tuning Support
#
# Pre-trained models can be customized using domain-specific datasets to improve performance for specialized tasks.
#
# ### 5. Open-Source Ecosystem
#
# Offers extensive documentation, tutorials, community support, and open-source libraries such as:
#
# * Transformers
# * Datasets
# * Accelerate
# * Tokenizers
#
# ### 6. Model Evaluation and Documentation
#
# Each model includes:
#
# * Model cards
# * Performance benchmarks
# * Usage examples
# * Licensing information
#
# ### 7. Multi-Modal Support
#
# Supports:
#
# * Natural Language Processing (NLP)
# * Computer Vision
# * Speech Processing
# * Multi-modal AI Applications
#
# ### 8. Community Collaboration
#
# Researchers and developers can share, download, and improve models collaboratively.
#
# ### Conclusion
#
# Hugging Face Hub significantly accelerates generative AI development by providing ready-to-use pre-trained models, fine-tuning capabilities, extensive documentation, and a strong open-source ecosystem, making it one of the most widely used platforms for AI development.
#
# ---
# # Question 5: Describe the process and advantages of navigating and using pre-trained models from the Hugging Face Hub.
#
# ## Answer
#
# ### Introduction
#
# The Hugging Face Hub is a platform that hosts thousands of pre-trained machine learning models for tasks such as text generation, sentiment analysis, translation, summarization, image classification, and more.
#
# ### Process of Using a Pre-trained Model
#
# 1. Create a Hugging Face account.
# 2. Visit the Hub at:
#    [https://huggingface.co/models](https://huggingface.co/models)
# 3. Search for a model based on the required task.
# 4. Review:
#
#    * Model card
#    * Documentation
#    * License
#    * Performance metrics
# 5. Install required libraries:
#
# ```python
# !pip install transformers torch
# ```
#
# 6. Load the model using Transformers:
#
# ```python
# from transformers import pipeline
#
# generator = pipeline("text-generation", model="gpt2")
#
# result = generator("Artificial Intelligence is", max_length=30)
#
# print(result[0]["generated_text"])
# ```
#
# ### Advantages
#
# * Large collection of pre-trained models
# * Easy integration using Transformers library
# * Reduces training time and cost
# * Community support and documentation
# * Supports NLP, Computer Vision, Audio, and Multimodal tasks
# * Fine-tuning capability for custom datasets
#
# ### Conclusion
#
# The Hugging Face Hub enables developers to quickly access and deploy state-of-the-art AI models without training them from scratch, accelerating AI development.

# %%
# !pip install chromadb sentence-transformers
import chromadb
from sentence_transformers import SentenceTransformer

# Create ChromaDB client
client = chromadb.Client()

# Create collection
collection = client.create_collection("my_documents")

# Sample documents
documents = [
    "Artificial Intelligence is transforming industries.",
    "Machine Learning is a subset of AI.",
    "Deep Learning uses neural networks."
]

# Load embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Generate embeddings
embeddings = model.encode(documents).tolist()

# Insert data
collection.add(
    ids=["1", "2", "3"],
    documents=documents,
    embeddings=embeddings
)

# Query
query = "What is Artificial Intelligence?"
query_embedding = model.encode([query]).tolist()

results = collection.query(
    query_embeddings=query_embedding,
    n_results=2
)

print(results["documents"])

# %%
# !pip install transformers torch -q

from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

result = generator(
    "Artificial Intelligence is",
    max_length=30,
    num_return_sequences=1
)

print(result[0]["generated_text"])

# %%
# Simulated Ollama Example

prompt = "Explain Machine Learning"

response = """
Machine Learning is a branch of Artificial Intelligence
that enables computers to learn from data and improve
their performance without explicit programming.
"""

print("Prompt:", prompt)
print("\nResponse:", response)

# %%
# !pip install sentence-transformers -q

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "AI stands for Artificial Intelligence.",
    "Machine Learning is a subset of AI.",
    "Deep Learning uses neural networks."
]

model = SentenceTransformer('all-MiniLM-L6-v2')

doc_embeddings = model.encode(documents)

query = "What is Machine Learning?"

query_embedding = model.encode([query])

similarities = cosine_similarity(
    query_embedding,
    doc_embeddings
)

best_match = documents[similarities.argmax()]

print("Question:", query)
print("Retrieved Document:", best_match)

# %%
# !pip install sentence-transformers -q

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

articles = [
    "Diabetes is a disease characterized by high blood sugar levels.",
    "Hypertension increases the risk of heart disease.",
    "Regular exercise improves cardiovascular health."
]

model = SentenceTransformer('all-MiniLM-L6-v2')

article_embeddings = model.encode(articles)

question = "What causes high blood sugar?"

question_embedding = model.encode([question])

similarity = cosine_similarity(
    question_embedding,
    article_embeddings
)

answer = articles[similarity.argmax()]

print("Question:", question)
print("Relevant Article:", answer)
'''Medical Research Articles
          │
          ▼
Text Chunking
          │
          ▼
Hugging Face Embedding Model
(all-MiniLM-L6-v2)
          │
          ▼
ChromaDB Vector Database
          │
          ▼
Semantic Retrieval
          │
          ▼
Ollama + Llama3
          │
          ▼
Medical Chatbot Response'''
